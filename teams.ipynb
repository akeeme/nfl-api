# %%
import json
import pandas as pd
import requests_html as rh

from scrapers.players import get_team_routes

# %%
sess = rh.HTMLSession()
baseUrl = 'https://www.nfl.com'
team_routes = get_team_routes()
team_routes = [x + '/' if not x.endswith('/') else x for x in team_routes]

# %%
def get_team_city(team_name: str) -> str:
    if len(team_name.split(' ')) > 2:
        return ' '.join(team_name.split(' ')[:-1])
    return team_name.split(' ')[0]  

def get_team_info_standings(r: rh.HTMLResponse) -> object:
    standing = r.html.xpath('//*[@id="main-content"]/div/div/section/div/div/div/div[2]')[0].element.text
    
    
    class return_vals:
        position = standing.split(' ')[0]
        division = " ".join(standing.split(' ')[1:])
    
    return return_vals

def get_team_w_l(r: rh.HTMLResponse) -> object:
    w_l = r.html.xpath('//*[@id="main-content"]/div/div/section/div/div/div/div[3]')[0].element.text
    
    class return_vals:
        wins = int(w_l.split('-')[0])
        losses = int(w_l.split('-')[1])
        tie = int(w_l.split('-')[2])
    
    return return_vals

def get_team_coach_data(r: rh.HTMLResponse) -> object:
    try:
        path = r.html.xpath('//*[@id="main-content"]/section[5]/div/div[1]/div/section/div/div[2]/ul/li')[0]
        
        coach_ = path.find('div.nfl-c-team-info__info-value')[0].element.text
        stadium_ = path.find('div.nfl-c-team-info__info-value')[1].element.text
        owners_ = path.find('div.nfl-c-team-info__info-value')[2].element.text.split(',')[0]
        established_ = int(path.find('div.nfl-c-team-info__info-value')[3].element.text)
        
        class return_vals:
            coach = coach_
            stadium = stadium_
            owners = owners_
            established = established_
        
        return return_vals
    except:
        path = r.html.xpath('//*[@id="main-content"]/section[4]/div/div[1]/div/section/div/div[2]/ul/li')[0]
        coach_ = path.find('div.nfl-c-team-info__info-value')[0].element.text
        stadium_ = path.find('div.nfl-c-team-info__info-value')[1].element.text
        owners_ = path.find('div.nfl-c-team-info__info-value')[2].element.text.split(',')[0]
        established_ = int(path.find('div.nfl-c-team-info__info-value')[3].element.text)
        
        class return_vals:
            coach = coach_
            stadium = stadium_
            owners = owners_
            established = established_
        
        return return_vals

# %%
def get_team_info(r: rh.HTMLResponse) -> object:
    team_standings = get_team_info_standings(r)
    team_w_l = get_team_w_l(r)
    team_name = r.html.xpath('//*[@id="main-content"]/div/div/section/div/div/div/div[1]')[0].element.text
    team_city = get_team_city(team_name)
    team_website = r.html.xpath('//*[@id="main-content"]/div/section/div/div/div/ul/li[1]/a')[0].attrs['href']
    coach_data = get_team_coach_data(r)
    
    class return_vals:
        name = team_name
        city = team_city
        website = team_website
        position = team_standings.position
        division = team_standings.division
        wins = team_w_l.wins
        losses = team_w_l.losses
        tie = team_w_l.tie
        coach = coach_data.coach
        stadium = coach_data.stadium
        owners = coach_data.owners
        established = coach_data.established
    
    return return_vals

# %%
def get_team_data(team_route: str):
    team_route = team_route + '/' if not team_route.endswith('/') else team_route
    sess = rh.HTMLSession()
    r = sess.get(baseUrl + team_route)
    
    team_data = []

    team_info = get_team_info(r)

    team_data.append({
        'name': team_info.name,
        'city': team_info.city,
        'website': team_info.website,
        'wins': team_info.wins,
        'losses': team_info.losses,
        'tie': team_info.tie,
        'position': team_info.position,
        'division': team_info.division,
        'coach': team_info.coach,
        'stadium': team_info.stadium,
        'owners': team_info.owners,
        'established': team_info.established
    })

    return team_data


def get_all_team_data(team_routes: list) -> pd.DataFrame:
    team_data = []
    for team_route in team_routes:
        team_data.extend(get_team_data(team_route))
    return pd.DataFrame(team_data)

# %%
df = get_team_data(team_routes[23])

# %%
df
# Out:
# [{'name': 'Washington Commanders',
#   'city': 'Washington',
#   'website': 'http://www.commanders.com/',
#   'wins': 7,
#   'losses': 5,
#   'tie': 1,
#   'position': '4th',
#   'division': 'NFC East',
#   'coach': 'Ron Rivera',
#   'stadium': 'FedExField',
#   'owners': 'Dan Snyder',
#   'established': 1932}]

# %%
df = get_all_team_data(team_routes)

# %%
df
# Out:
#                      name           city                              website  \
# 0         Atlanta Falcons        Atlanta      https://www.atlantafalcons.com/
# 1          Dallas Cowboys         Dallas       https://www.dallascowboys.com/
# 2        Seattle Seahawks        Seattle            https://www.seahawks.com/
# 3       Minnesota Vikings      Minnesota             https://www.vikings.com/
# 4           Buffalo Bills        Buffalo        https://www.buffalobills.com/
# 5    Tampa Bay Buccaneers      Tampa Bay          https://www.buccaneers.com/
# 6         New York Giants       New York              https://www.giants.com/
# 7    New England Patriots    New England            https://www.patriots.com/
# 8      Kansas City Chiefs    Kansas City              https://www.chiefs.com/
# 9    Los Angeles Chargers    Los Angeles            https://www.chargers.com/
# 10     Indianapolis Colts   Indianapolis               https://www.colts.com/
# 11     New Orleans Saints    New Orleans    https://www.neworleanssaints.com/
# 12      Green Bay Packers      Green Bay             https://www.packers.com/
# 13       Cleveland Browns      Cleveland     https://www.clevelandbrowns.com/
# 14    San Francisco 49ers  San Francisco               https://www.49ers.com/
# 15       Baltimore Ravens      Baltimore     https://www.baltimoreravens.com/
# 16      Carolina Panthers       Carolina            https://www.panthers.com/
# 17          Chicago Bears        Chicago        https://www.chicagobears.com/
# 18          New York Jets       New York         https://www.newyorkjets.com/
# 19    Pittsburgh Steelers     Pittsburgh            https://www.steelers.com/
# 20    Philadelphia Eagles   Philadelphia  https://www.philadelphiaeagles.com/
# 21         Houston Texans        Houston       https://www.houstontexans.com/
# 22      Arizona Cardinals        Arizona         https://www.azcardinals.com/
# 23  Washington Commanders     Washington           http://www.commanders.com/
# 24          Detroit Lions        Detroit        https://www.detroitlions.com/
# 25   Jacksonville Jaguars   Jacksonville             https://www.jaguars.com/
# 26         Denver Broncos         Denver       https://www.denverbroncos.com/
# 27       Tennessee Titans      Tennessee        https://www.titansonline.com/
# 28       Los Angeles Rams    Los Angeles             https://www.therams.com/
# 29      Las Vegas Raiders      Las Vegas             https://www.raiders.com/
# 30     Cincinnati Bengals     Cincinnati             https://www.bengals.com/
# 31         Miami Dolphins          Miami       https://www.miamidolphins.com/
#
#     wins  losses  tie position   division                    coach  \
# 0      5       8    0      2nd  NFC South             Arthur Smith
# 1      9       3    0      2nd   NFC East            Mike McCarthy
# 2      7       5    0      2nd   NFC West             Pete Carroll
# 3     10       2    0      1st  NFC North          Kevin O'Connell
# 4      9       3    0      1st   AFC East           Sean McDermott
# 5      5       6    0      1st  NFC South              Todd Bowles
# 6      7       4    1      3rd   NFC East             Brian Daboll
# 7      6       6    0      4th   AFC East           Bill Belichick
# 8      9       3    0      1st   AFC West                Andy Reid
# 9      6       6    0      2nd   AFC West           Brandon Staley
# 10     4       8    1      2nd  AFC South  Jeff Saturday (Interim)
# 11     4       8    0      4th  NFC South             Dennis Allen
# 12     5       8    0      3rd  NFC North             Matt LaFleur
# 13     5       7    0      3rd  AFC North          Kevin Stefanski
# 14     8       4    0      1st   NFC West            Kyle Shanahan
# 15     8       4    0      1st  AFC North            John Harbaugh
# 16     4       8    0      3rd  NFC South    Steve Wilks (Interim)
# 17     3      10    0      4th  NFC North            Matt Eberflus
# 18     7       5    0      3rd   AFC East             Robert Saleh
# 19     5       7    0      4th  AFC North              Mike Tomlin
# 20    11       1    0      1st   NFC East            Nick Sirianni
# 21     1      10    1      4th  AFC South              Lovie Smith
# 22     4       8    0      3rd   NFC West          Kliff Kingsbury
# 23     7       5    1      4th   NFC East               Ron Rivera
# 24     5       7    0      2nd  NFC North             Dan Campbell
# 25     4       8    0      3rd  AFC South            Doug Pederson
# 26     3       9    0      4th   AFC West        Nathaniel Hackett
# 27     7       5    0      1st  AFC South              Mike Vrabel
# 28     3       9    0      4th   NFC West               Sean McVay
# 29     5       7    0      3rd   AFC West           Josh McDaniels
# 30     8       4    0      2nd  AFC North               Zac Taylor
# 31     8       4    0      2nd   AFC East            Mike McDaniel
#
#                             stadium                                owners  \
# 0             Mercedes-Benz Stadium                          Arthur Blank
# 1                      AT&T Stadium                           Jerry Jones
# 2                       Lumen Field      Seattle Seahawks Ownership Trust
# 3                 U.S. Bank Stadium                             Zygi Wilf
# 4                  Highmark Stadium                  Kim and Terry Pegula
# 5             Raymond James Stadium                          Bryan Glazer
# 6                   MetLife Stadium                             John Mara
# 7                  Gillette Stadium                          Robert Kraft
# 8   GEHA Field at Arrowhead Stadium                            Clark Hunt
# 9                      SoFi Stadium                Alex Spanos and Family
# 10                Lucas Oil Stadium                             Jim Irsay
# 11                Caesars Superdome                          Gayle Benson
# 12                    Lambeau Field                     Green Bay Packers
# 13              FirstEnergy Stadium                  Dee and Jimmy Haslam
# 14                  Levi's® Stadium                              Jed York
# 15                 M&T Bank Stadium                       Steve Bisciotti
# 16          Bank of America Stadium                          David Tepper
# 17                    Soldier Field               Virginia Halas McCaskey
# 18                  MetLife Stadium                Robert Wood Johnson IV
# 19                 Acrisure Stadium              Art Rooney II and Family
# 20          Lincoln Financial Field                         Jeffrey Lurie
# 21                      NRG Stadium                      Janice S. McNair
# 22               State Farm Stadium                       Michael Bidwill
# 23                       FedExField                            Dan Snyder
# 24                       Ford Field                           Martha Ford
# 25                  TIAA Bank Field                           Shahid Khan
# 26       Empower Field at Mile High  Walton-Penner Family Ownership Group
# 27                   Nissan Stadium                      Amy Adams Strunk
# 28                     SoFi Stadium                          Stan Kroenke
# 29                Allegiant Stadium                  Carol and Mark Davis
# 30                   Paycor Stadium                            Mike Brown
# 31                Hard Rock Stadium                       Stephen M. Ross
#
#     established
# 0          1966
# 1          1960
# 2          1976
# 3          1961
# 4          1960
# 5          1976
# 6          1925
# 7          1960
# 8          1960
# 9          1960
# 10         1944
# 11         1967
# 12         1921
# 13         1946
# 14         1946
# 15         1996
# 16         1995
# 17         1920
# 18         1960
# 19         1933
# 20         1933
# 21         2002
# 22         1920
# 23         1932
# 24         1930
# 25         1995
# 26         1960
# 27         1960
# 28         1937
# 29         1960
# 30         1968
# 31         1966

# %%
df.columns
# Out:
# Index(['name', 'city', 'website', 'wins', 'losses', 'tie', 'position',
#        'division', 'coach', 'stadium', 'owners', 'established'],
#       dtype='object')
